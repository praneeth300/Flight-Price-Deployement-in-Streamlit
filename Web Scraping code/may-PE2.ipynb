# %%
import pandas as pd
import json
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait 
from selenium.webdriver.support import expected_conditions
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
from datetime import date, timedelta, datetime
import time
df=pd.read_csv("cities.csv")

# %%
df
# Out:
#    Code IMP_codes
# 0   AGR       DEL
# 1   DIB       BOM
# 2   HYD       BLR
# 3   BHJ       HYD
# 4   HBX       MAA
# ..  ...       ...
# 79  IXS       NaN
# 80  CNN       NaN
# 81  GOI       NaN
# 82  AMD       NaN
# 83  TIR       NaN
#
# [84 rows x 2 columns]

# %%
df["IMP_codes"].iloc[29]
# Out:
# 'TRZ'

# %%
from tqdm import tqdm
price=[]
cities=[]
departure_time=[]
arrival_time=[]
via=[]
airline=[]
cabin=[]
scraping_time = []
driver = webdriver.Chrome("C:\Program Files (x86)\chromedriver.exe")

for z in range(30, 32):
    driver.refresh()
    for m in range(29, 30):
        driver.refresh()
        for n in range(30):
            driver.refresh()
            if df["IMP_codes"].iloc[m]!=df["IMP_codes"].iloc[n]:
                print("source=",m, "destination=",n, "Dates=",z)
                print(df["IMP_codes"].iloc[m],df["IMP_codes"].iloc[n])
                k=''
                if(z<10):
                    k='0'
                url="https://www.makemytrip.com/flight/search?itinerary="+df["IMP_codes"].iloc[m]+"-"+df["IMP_codes"].iloc[n]+"-"+k+str(z)+"/05/2021&tripType=O&paxType=A-1_C-0_I-0&intl=false&cabinClass=PE&ccde=IN&lang=eng"
                #driver = webdriver.Chrome("C:/chromedriver.exe")
                driver.get(url)
                soup=BeautifulSoup(driver.page_source, 'lxml')

                price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})
                flights_info=soup.find_all('p',attrs={'class': 'flightDetailsHead'})
                time_info=soup.find_all('p',attrs={'class':"blackText fontSize18 blackFont appendBottom2 makeFlex hrtlCenter"})
                layover_info=soup.find_all('p',attrs={'class': 'flightsLayoverInfo'})
                airline_info=soup.find_all('span',attrs={'class': 'boldFont blackText airlineName'})
                now1 = datetime.now()
                print("now =", now1)

#price_info
                for i,j in enumerate(price_info):
                    if i<30:
                       a=str(j)
                       price.append(a[43:len(a)-4])
                      
    #flights_info
                for i,j in enumerate(flights_info):
                    if i<60:
                        k=str(j)
                        if len(k)>45:
                            cities.append(k[29:(len(k)-4)])
                            scraping_time.append(now1)

    #time_info
                for i,j in enumerate(time_info):
                    if i<60:
                        k=str(j)
                        if (i%2==0):
                            departure_time.append(k[82:87])
                        if (i%2!=0):
                            arrival_time.append(k[82:87])

    #layover_info
                for i,j in enumerate(layover_info):
                    if i<30:
                        k=str(j)
                        via.append(k[30:len(k)-4])

    #airline_info
                for i,j in enumerate(airline_info):
                    if i<30:            
                        k=str(j)
                        airline.append(k[45:len(k)-7])
                print("**"*50)
                print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline),len(scraping_time))
# Out:
# source= 29 destination= 0 Dates= 30
# TRZ DEL
# now = 2021-05-18 20:18:14.411469
# ****************************************************************************************************
# 0 0 0 0 0 0 0
# source= 29 destination=
# ****************************************************************************************************
# 0 0 0 0 0 0 0
# source= 29 destination= 4 Dates= 31
# TRZ MAA
# now = 2021-05-18 20:39:18.642851
# ****************************************************************************************************
# 0 0 0 0 0 0 0
# source= 29 destination= 5 Dates= 31
# TRZ CCU
# now = 2021-05-18 20:39:44.192275
# ****************************************************************************************************
# 0 0 0 0 0 0 0
# source= 29 destination= 6 Dates= 31
# TRZ COK
# now = 2021-05-18 20:40:05.221028
# ****************************************************************************************************
# 0 0 0 0 0 0 0
# source= 29 destination= 7 Dates= 31
# TRZ GOI
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-11-4b907d23a3d5> in <module>
#      25                 #driver = webdriver.Chrome("C:/chromedriver.exe")
#      26                 driver.get(url)
# ---> 27                 soup=BeautifulSoup(driver.page_source, 'lxml')
#      28
#      29                 price_info=soup.find_all('p',attrs={'class': 'blackText fontSize18 blackFont'})
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=90.0.4430.212)

# %%
data = pd.DataFrame(
    {'Price':price,
     'Cities':cities,
     'departure_time':departure_time,
     'arrival_time':arrival_time, 
     'layeover':via,
     'Airline':airline,
     'Scraping_Time':scraping_time
    })

# %%
data
# Out:
#       Price                            Cities departure_time arrival_time  \
# 0     4,850      Indore to New Delhi , 30 May          10:30        11:50
# 1     5,910    Srinagar to New Delhi , 30 May          12:50        14:30
# 2     5,176    Srinagar to New Delhi , 30 May          13:15        14:45
# 3     5,176    Srinagar to New Delhi , 30 May          08:50        10:30
# 4     5,176    Srinagar to New Delhi , 30 May          12:35        14:15
# ..      ...                               ...            ...          ...
# 69    9,338     Port Blair to Mumbai , 30 May          09:50        23:50
# 70    9,338     Port Blair to Mumbai , 30 May          09:50        08:20
# 71   11,092  Port Blair to Bengaluru , 30 May          09:50        09:05
# 72    5,588    Port Blair to Chennai , 30 May          09:50        12:05
# 73    5,313    Port Blair to Kolkata , 30 May          11:55        14:20
#
#               layeover   Airline              Scraping_Time
# 0             Non stop   Vistara 2021-05-18 17:09:22.350367
# 1             Non stop   Vistara 2021-05-18 17:41:04.236478
# 2             Non stop  Spicejet 2021-05-18 17:41:04.236478
# 3             Non stop  Spicejet 2021-05-18 17:41:04.236478
# 4             Non stop  Spicejet 2021-05-18 17:41:04.236478
# ..                 ...       ...                        ...
# 69  1 stop via Chennai  Spicejet 2021-05-18 18:54:08.033309
# 70  1 stop via Chennai  Spicejet 2021-05-18 18:54:08.033309
# 71  1 stop via Chennai  Spicejet 2021-05-18 18:54:26.448875
# 72            Non stop  Spicejet 2021-05-18 18:54:55.075452
# 73            Non stop   Vistara 2021-05-18 18:54:58.842242
#
# [74 rows x 7 columns]

# %%
print(len(departure_time), len(price),len(cities),len(arrival_time),len(via),len(airline), len(scraping_time))
# Out:
# 74 74 74 74 74 74 74

# %%
data.to_csv("new_pe_may30_5th.csv", index = False)

# %%
df.tail()
# Out:
#    Code IMP_codes
# 79  IXS       NaN
# 80  CNN       NaN
# 81  GOI       NaN
# 82  AMD       NaN
# 83  TIR       NaN
